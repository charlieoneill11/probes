# %%
# ------------------------------------------------------------------
# Install required libraries if not already installed (silent install)
# ------------------------------------------------------------------
# Uncomment if needed:
# !pip install sentence_transformers --quiet

# ------------------------------------------------------------------
# Imports
# ------------------------------------------------------------------
import json
import numpy as np
import torch
from IPython.display import HTML, display
import html
import os
import nltk
from transformers import AutoTokenizer
from transformer_lens import HookedTransformer
from sentence_transformers import SentenceTransformer, util

# Download necessary NLTK data (for tokenization, if needed)
nltk.download('punkt')

# ------------------------------------------------------------------
# 1. GLOBAL MODEL LOADING
# ------------------------------------------------------------------
def load_model(model_name="gemma-2-2b"):
    """Load the model and return it for reuse"""
    print(f"Loading model: {model_name}")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = HookedTransformer.from_pretrained(model_name, device=device)
    return model, model.tokenizer, device

global_model, global_tokenizer, global_device = load_model()

# ------------------------------------------------------------------
# 2. PROCESS EXAMPLE
# ------------------------------------------------------------------
def process_example(model, tokenizer, hook_name, probe, text, device):
    """
    Encode text, run model forward pass, apply probe to get token-level activations.
    Returns (list_of_token_strings, list_of_scores)
    """
    tokens = tokenizer.encode(text, return_tensors="pt").to(device)
    token_strs = [tokenizer.decode(t).replace('▁', ' ') for t in tokens[0]]
    
    with torch.no_grad():
        _, cache = model.run_with_cache(tokens, names_filter=[hook_name])
        activations = cache[hook_name]

    scores = []
    for pos in range(activations.shape[1]):
        pos_activations = activations[0, pos].cpu().numpy().reshape(1, -1)
        score = probe.predict_proba(pos_activations)[0, 1]  # Probability of class=1
        scores.append(float(score))
    
    return token_strs, scores

# ------------------------------------------------------------------
# 3. SENTENCE-TRANSFORMER FOR SEMANTIC SIMILARITY
# ------------------------------------------------------------------
semantic_model = SentenceTransformer('all-MiniLM-L6-v2')

def compute_semantic_similarity(phrase, concept_text):
    """
    Compute cosine similarity between 'phrase' and 'concept_text' using Sentence-BERT.
    """
    emb_phrase = semantic_model.encode(phrase, convert_to_tensor=True)
    emb_concept = semantic_model.encode(concept_text, convert_to_tensor=True)
    return util.cos_sim(emb_phrase, emb_concept).item()

# ------------------------------------------------------------------
# 4. ACTIVATION VALIDATION (DETAILED)
# ------------------------------------------------------------------
def compute_activation_validation_details(token_strs, scores, concept_text):
    """
    Splits tokens into groups based on '.' or ','.
    For each group, computes semantic similarity to 'concept_text'.
    Then for each token in that group, calculates:
        activation_validation = activation * abs(similarity)
    Returns a list of details (one entry per token).
    """
    groups = []
    current_group_tokens = []
    current_group_scores = []

    # Group tokens by punctuation ('.' or ',')
    for token, score in zip(token_strs, scores):
        current_group_tokens.append(token)
        current_group_scores.append(score)
        if token.strip() in ['.', ',']:
            group_string = "".join(current_group_tokens).strip()
            groups.append((group_string, current_group_scores.copy()))
            current_group_tokens = []
            current_group_scores = []

    if current_group_tokens:
        group_string = "".join(current_group_tokens).strip()
        groups.append((group_string, current_group_scores.copy()))
    
    details = []
    for group_string, group_scores in groups:
        similarity = compute_semantic_similarity(group_string, concept_text)
        # Use absolute similarity in the multiplication
        for activation in group_scores:
            act_val = activation * abs(similarity)
            details.append({
                "token": None,  # to be filled in later in match_tokens_to_groups
                "activation": activation,
                "group": group_string,
                "concept": concept_text,
                "similarity": similarity,
                "activation_validation": act_val
            })
    return details

def compute_activation_validation_score(token_strs, scores, concept_text):
    """
    A simpler aggregator that sums the activation-validation (using abs similarity).
    """
    details = compute_activation_validation_details(token_strs, scores, concept_text)
    total = sum(d["activation_validation"] for d in details)
    return total

# ------------------------------------------------------------------
# 5. PRINT TOKEN-LEVEL DETAILS AS TEXT BLOCK
# ------------------------------------------------------------------
def match_tokens_to_groups(token_strs, scores, concept_text):
    """
    Similar to compute_activation_validation_details, but returns row-level data with
    the actual token included. This helps list only tokens with non-zero activation.
    """
    rows = []
    current_group_tokens = []
    current_group_indices = []
    current_group_scores = []

    for i, (token, score) in enumerate(zip(token_strs, scores)):
        current_group_tokens.append(token)
        current_group_scores.append(score)
        current_group_indices.append(i)
        if token.strip() in ['.', ',']:
            group_string = "".join(current_group_tokens).strip()
            similarity = compute_semantic_similarity(group_string, concept_text)
            for idx, tok, sc in zip(current_group_indices, current_group_tokens, current_group_scores):
                act_val = sc * abs(similarity)
                rows.append({
                    "index": idx,
                    "token": tok,
                    "group": group_string,
                    "activation": sc,
                    "concept": concept_text,
                    "similarity": similarity,
                    "activation_validation": act_val
                })
            current_group_tokens = []
            current_group_scores = []
            current_group_indices = []
    
    if current_group_tokens:
        group_string = "".join(current_group_tokens).strip()
        similarity = compute_semantic_similarity(group_string, concept_text)
        for idx, tok, sc in zip(current_group_indices, current_group_tokens, current_group_scores):
            act_val = sc * abs(similarity)
            rows.append({
                "index": idx,
                "token": tok,
                "group": group_string,
                "activation": sc,
                "concept": concept_text,
                "similarity": similarity,
                "activation_validation": act_val
            })
    return rows

def print_token_contributions_table(rows, label="Example Text"):
    """
    Print a fixed-width table of tokens with non-zero activation.
    Columns: Index, Token, Group, Activation, Similarity, ActVal
    Uses precise alignment to avoid misalignment.
    """
    threshold = 0.001
    filtered = [r for r in rows if abs(r["activation"]) > threshold]
    
    if not filtered:
        print(f"\nNo non-zero activations found for {label}.")
        return
    
    # Define column widths & alignment
    # Index: 5 chars (left)
    # Token: 15 chars (left)
    # Group: 75 chars (left)
    # Activation, Similarity, ActVal: 12 chars each (right), with 4 decimals
    header_format = "{:<5} | {:<15} | {:<75} | {:>12} | {:>12} | {:>12}"
    line_width = 5 + 3 + 15 + 3 + 75 + 3 + 12 + 3 + 12 + 3 + 12
    
    header = header_format.format("Idx", "Token", "Group", "Activation", "Similarity", "ActVal")
    separator = "-" * line_width
    
    table_lines = [f"\n--- Token-Level Contributions ({label}) ---", header, separator]
    
    for r in filtered:
        idx_str = f"{r['index']}"
        token_str = r["token"]
        group_str = r["group"]
        activation_str = f"{r['activation']:.4f}"
        similarity_str = f"{r['similarity']:.4f}"
        av_str = f"{r['activation_validation']:.4f}"
        
        line = header_format.format(
            idx_str,
            token_str[:15],  # Truncate token if it's longer than 15
            group_str[:75],  # Truncate group if it's longer than 50
            activation_str,
            similarity_str,
            av_str
        )
        table_lines.append(line)
    
    print("\n".join(table_lines))

# ------------------------------------------------------------------
# 6. VALIDATION FUNCTION (MODIFIED TO PRINT DETAILS)
# ------------------------------------------------------------------
def validate_example_unrelated(example_path, unrelated_path, concept_key, concept_string=None, layer=22):
    """
    1) Load the probe for the concept.
    2) Compute token-level activations for example and unrelated texts.
    3) Sum activation validation (using abs semantic similarity) and print overall difference.
    4) Print a detailed table (text block) of non-zero tokens for both texts.
    """
    if concept_string is None:
        concept_string = concept_key.replace("_", " ")
    
    probe_dir = os.path.join("probes", concept_key)
    joblib_path = os.path.join(probe_dir, "probe.joblib")
    pkl_path = os.path.join(probe_dir, "probe.pkl")
    config_path = os.path.join(probe_dir, "config.json")

    if os.path.exists(joblib_path):
        import joblib
        probe = joblib.load(joblib_path)
        print(f"Loaded probe from {joblib_path}")
    elif os.path.exists(pkl_path):
        import pickle
        with open(pkl_path, 'rb') as f:
            probe = pickle.load(f)
        print(f"Loaded probe from {pkl_path}")
    else:
        print(f"Probe not found at {joblib_path} or {pkl_path}")
        return
    
    if os.path.exists(config_path):
        with open(config_path, "r") as f:
            config = json.load(f)
        concept_string = config.get("concept", concept_string)

    hook_name = f"blocks.{layer}.hook_resid_post"

    # Process example text
    with open(example_path, "r", encoding="utf-8") as f:
        example_text = f.read().strip()
    example_tokens, example_scores = process_example(global_model, global_tokenizer, hook_name, probe, example_text, global_device)
    example_activation_validation = compute_activation_validation_score(example_tokens, example_scores, concept_string)

    # Process unrelated text
    with open(unrelated_path, "r", encoding="utf-8") as f:
        unrelated_text = f.read().strip()
    unrelated_tokens, unrelated_scores = process_example(global_model, global_tokenizer, hook_name, probe, unrelated_text, global_device)
    unrelated_activation_validation = compute_activation_validation_score(unrelated_tokens, unrelated_scores, concept_string)

    overall_difference = example_activation_validation - unrelated_activation_validation

    # Print summary results
    print("\n=== Activation Validation Results ===")
    print(f"Concept Key: {concept_key}")
    print(f"Concept String: '{concept_string}'")
    print(f"Example Text Score:   {example_activation_validation:.4f}")
    print(f"Unrelated Text Score: {unrelated_activation_validation:.4f}")
    print(f"Overall Difference:   {overall_difference:.4f}")

    # Get detailed rows and print tables for each text
    example_rows = match_tokens_to_groups(example_tokens, example_scores, concept_string)
    print_token_contributions_table(example_rows, label="Example Text")

    unrelated_rows = match_tokens_to_groups(unrelated_tokens, unrelated_scores, concept_string)
    print_token_contributions_table(unrelated_rows, label="Unrelated Text")

# ------------------------------------------------------------------
# 7. LIST AVAILABLE CONCEPTS
# ------------------------------------------------------------------
def list_available_concepts(json_file_path):
    with open(json_file_path, 'r') as file:
        data = json.load(file)
    concepts = data['concepts']
    return [concept.replace(" ", "_") for concept in concepts]

# ------------------------------------------------------------------
# 8. VISUALIZATION FUNCTION
# ------------------------------------------------------------------
def visualize_concept_on_text(text, concept_key, model=global_model, tokenizer=global_tokenizer, layer=22):
    probe_dir = os.path.join("probes", concept_key)
    joblib_path = os.path.join(probe_dir, "probe.joblib")
    pkl_path = os.path.join(probe_dir, "probe.pkl")
    config_path = os.path.join(probe_dir, "config.json")

    if os.path.exists(joblib_path):
        import joblib
        probe = joblib.load(joblib_path) 
        print(f"Loaded probe from {joblib_path}")
    elif os.path.exists(pkl_path):
        import pickle
        with open(pkl_path, 'rb') as f:
            probe = pickle.load(f)
        print(f"Loaded probe from {pkl_path}")
    else:
        print(f"Probe not found at {joblib_path} or {pkl_path}")
        return None

    if not os.path.exists(config_path):
        print(f"Config not found at {config_path}")
        return None

    with open(config_path, "r") as f:
        config = json.load(f)

    concept = config.get("concept", concept_key.replace("_", " "))
    hook_name = f"blocks.{layer}.hook_resid_post"
    tokens, scores = process_example(model, tokenizer, hook_name, probe, text, global_device)

    html_output = f"<h2>Activation visualization for concept: '{concept}'</h2>"
    html_output += "<div style='line-height: 2.5; font-family: monospace; font-size: 14px;'>"

    for i, (token, score) in enumerate(zip(tokens, scores)):
        escaped_token = html.escape(token)
        green_intensity = 255
        other_intensity = int(255 * (1 - score))
        color = f"rgb({other_intensity}, {green_intensity}, {other_intensity})"
        html_output += f"""<span title='Token: "{escaped_token}"
Position: #{i}
Activation: {score:.4f}' style='background-color: {color}; padding: 3px; border-radius: 3px; margin: 1px;'>{escaped_token}</span>"""
    
    html_output += "</div>"
    return HTML(html_output)

# ------------------------------------------------------------------
# 9. MAIN USAGE EXAMPLE
# ------------------------------------------------------------------
# Load example and unrelated text
with open("inputs/example.txt", "r", encoding="utf-8") as f:
    example_text = f.read()

with open("inputs/unrelated.txt", "r", encoding="utf-8") as f:
    unrelated_text = f.read()

# Load concepts and process each
concepts = list_available_concepts("inputs/concepts_copy.json")
for concept in concepts:
    print("\n============================================")
    print(f"Concept: {concept}")
    
    print("\n--- Visualizing Example Text ---")
    display(visualize_concept_on_text(example_text, concept))

    print("\n--- Visualizing Unrelated Text ---")
    display(visualize_concept_on_text(unrelated_text, concept))

    print("\n--- Validation Results ---")
    validate_example_unrelated("inputs/example.txt", "inputs/unrelated.txt", concept)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:root:You tried to specify center_unembed=True for a model using logit softcap, but this can't be done! Softcapping is not invariant upon adding a constant Setting center_unembed=False instead.
# Loading model: gemma-2-2b
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model gemma-2-2b into HookedTransformer
#
# ============================================
# Concept: heavy_alcohol_use
#
# --- Visualizing Example Text ---
# Loaded probe from probes/heavy_alcohol_use/probe.joblib
# <h2>Activation visualization for concept: 'heavy alcohol use'</h2><div style='line-height: 2.5; font-family: monospace; font-size: 14px;'><span title='Token: "&lt;bos&gt;"
# Position: #0
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&lt;bos&gt;</span><span title='Token: "John"
# Position: #1
# Activation: 0.0000' style='background-color: rgb(254, 255, 254); padding: 3px; border-radius: 3px; margin: 1px;'>John</span><span title='Token: " Doe"
# Position: #2
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> Doe</span><span title='Token: ","
# Position: #3
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " a"
# Position: #4
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " "
# Position: #5
# Activation: 0.0000' style='background-color: rgb(254, 255, 254); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "5"
# Position: #6
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>5</span><span title='Token: "4"
# Position: #7
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>4</span><span title='Token: "-"
# Position: #8
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "year"
# Position: #9
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>year</span><span title='Token: "-"
# Position: #10
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "old"
# Position: #11
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>old</span><span title='Token: " male"
# Position: #12
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> male</span><span title='Token: ","
# Position: #13
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " presents"
# Position: #14
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> presents</span><span title='Token: " for"
# Position: #15
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " a"
# Position: #16
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " routine"
# Position: #17
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> routine</span><span title='Token: " check"
# Position: #18
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> check</span><span title='Token: "-"
# Position: #19
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "up"
# Position: #20
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>up</span><span title='Token: " with"
# Position: #21
# Activation: 0.0000' style='background-color: rgb(254, 255, 254); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " occasional"
# Position: #22
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> occasional</span><span title='Token: " headaches"
# Position: #23
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> headaches</span><span title='Token: " and"
# Position: #24
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> and</span><span title='Token: " fatigue"
# Position: #25
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> fatigue</span><span title='Token: " persist"
# Position: #26
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> persist</span><span title='Token: "ing"
# Position: #27
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>ing</span><span title='Token: " for"
# Position: #28
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " three"
# Position: #29
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> three</span><span title='Token: " months"
# Position: #30
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> months</span><span title='Token: "."
# Position: #31
# Activation: 0.0000' style='background-color: rgb(254, 255, 254); padding: 3px; border-radius: 3px; margin: 1px;'>.</span><span title='Token: " The"
# Position: #32
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> The</span><span title='Token: " headaches"
# Position: #33
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> headaches</span><span title='Token: " occur"
# Position: #34
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> occur</span><span title='Token: " "
# Position: #35
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "2"
# Position: #36
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>2</span><span title='Token: "–"
# Position: #37
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>–</span><span title='Token: "3"
# Position: #38
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>3</span><span title='Token: " times"
# Position: #39
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> times</span><span title='Token: " per"
# Position: #40
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> per</span><span title='Token: " week"
# Position: #41
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> week</span><span title='Token: ","
# Position: #42
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " are"
# Position: #43
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> are</span><span title='Token: " mild"
# Position: #44
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> mild</span><span title='Token: " to"
# Position: #45
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> to</span><span title='Token: " moderate"
# Position: #46
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> moderate</span><span title='Token: " with"
# Position: #47
# Activation: 0.0000' style='background-color: rgb(25
# --- Visualizing Unrelated Text ---
# Loaded probe from probes/heavy_alcohol_use/probe.joblib
# <h2>Activation visualization for concept: 'heavy alcohol use'</h2><div style='line-height: 2.5; font-family: monospace; font-size: 14px;'><span title='Token: "&lt;bos&gt;"
# Position: #0
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&lt;bos&gt;</span><span title='Token: "Michael"
# Position: #1
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>Michael</span><span title='Token: " Chen"
# Position: #2
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> Chen</span><span title='Token: ","
# Position: #3
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " a"
# Position: #4
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " "
# Position: #5
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "3"
# Position: #6
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>3</span><span title='Token: "2"
# Position: #7
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>2</span><span title='Token: "-"
# Position: #8
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "year"
# Position: #9
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>year</span><span title='Token: "-"
# Position: #10
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "old"
# Position: #11
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>old</span><span title='Token: " software"
# Position: #12
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> software</span><span title='Token: " developer"
# Position: #13
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> developer</span><span title='Token: ","
# Position: #14
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " schedules"
# Position: #15
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> schedules</span><span title='Token: " a"
# Position: #16
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " meeting"
# Position: #17
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> meeting</span><span title='Token: " with"
# Position: #18
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " his"
# Position: #19
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> his</span><span title='Token: " team"
# Position: #20
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> team</span><span title='Token: " lead"
# Position: #21
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> lead</span><span title='Token: " to"
# Position: #22
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> to</span><span title='Token: " discuss"
# Position: #23
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> discuss</span><span title='Token: " ongoing"
# Position: #24
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> ongoing</span><span title='Token: " challenges"
# Position: #25
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> challenges</span><span title='Token: " with"
# Position: #26
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " the"
# Position: #27
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> the</span><span title='Token: " company"
# Position: #28
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> company</span><span title='Token: "&#x27;"
# Position: #29
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&#x27;</span><span title='Token: "s"
# Position: #30
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>s</span><span title='Token: " flagship"
# Position: #31
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> flagship</span><span title='Token: " application"
# Position: #32
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> application</span><span title='Token: "."
# Position: #33
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>.</span><span title='Token: " He"
# Position: #34
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> He</span><span title='Token: "&#x27;"
# Position: #35
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&#x27;</span><span title='Token: "s"
# Position: #36
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>s</span><span title='Token: " been"
# Position: #37
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> been</span><span title='Token: " experiencing"
# Position: #38
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> experiencing</span><span title='Token: " intermittent"
# Position: #39
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> intermittent</span><span title='Token: " system"
# Position: #40
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> system</span><span title='Token: " crashes"
# Position: #41
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> crashes</span><span title='Token: " and"
# Position: #42
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> and</span><span title='Token: " performance"
# Position: #43
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> performance</span><span title='Token: " issues"
# Position: #44
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> issues</span><span title='Token: " for"
# Position: #45
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " approximately"
# Position: #46
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-r
# --- Validation Results ---
# Loaded probe from probes/heavy_alcohol_use/probe.joblib
#
# === Activation Validation Results ===
# Concept Key: heavy_alcohol_use
# Concept String: 'heavy alcohol use'
# Example Text Score:   1.2905
# Unrelated Text Score: 0.0000
# Overall Difference:   1.2905
#
# --- Token-Level Contributions (Example Text) ---
# Idx   Token           Group                                    Activation   Similarity   ActVal
# -----------------------------------------------------------------------------------------------------
# 126   .               or depressive symptoms.                  0.0219       0.1948       0.0043
# 164   ).              though BP remains mildly elevated (14... 0.9126       0.2222       0.2028
# 247   .               with a BMI of 28.                        0.0762       0.1379       0.0105
# 252   ).              7 (overweight). Physical exam is unre... 0.9389       0.2145       0.2014
# 354   ).              6% (near prediabetic range). Given hi... 0.2141       0.2097       0.0449
# 397   .               in line with Australian guidelines.      1.0000       0.1629       0.1629
# 440    heavy          heavy alcohol intake,                    0.0021       0.8421       0.0018
# 454   .               should be considered before initiation.  1.0000       0.0228       0.0228
# 455
#                Answer:
# The LDL-C was 160 which is el... 1.0000       0.2193       0.2193
# 456                   Answer:
# The LDL-C was 160 which is el... 0.2050       0.2193       0.0449
# 457
#                Answer:
# The LDL-C was 160 which is el... 1.0000       0.2193       0.2193
# 535   .               atorvastatin is often first line.        0.0055       0.1198       0.0007
# 538    has            The patient has never been on a stati... 0.0564       -0.0329      0.0019
# 546   .               The patient has never been on a stati... 0.3325       -0.0329      0.0110
# 560   .               They should therefore start on 20mg d... 0.9978       0.1423       0.1420
#
# No non-zero activations found for Unrelated Text.
#
# ============================================
# Concept: elevated_LDL_cholesterol
#
# --- Visualizing Example Text ---
# Loaded probe from probes/elevated_LDL_cholesterol/probe.joblib
# <h2>Activation visualization for concept: 'elevated LDL cholesterol'</h2><div style='line-height: 2.5; font-family: monospace; font-size: 14px;'><span title='Token: "&lt;bos&gt;"
# Position: #0
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&lt;bos&gt;</span><span title='Token: "John"
# Position: #1
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>John</span><span title='Token: " Doe"
# Position: #2
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> Doe</span><span title='Token: ","
# Position: #3
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " a"
# Position: #4
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " "
# Position: #5
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "5"
# Position: #6
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>5</span><span title='Token: "4"
# Position: #7
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>4</span><span title='Token: "-"
# Position: #8
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "year"
# Position: #9
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>year</span><span title='Token: "-"
# Position: #10
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "old"
# Position: #11
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>old</span><span title='Token: " male"
# Position: #12
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> male</span><span title='Token: ","
# Position: #13
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " presents"
# Position: #14
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> presents</span><span title='Token: " for"
# Position: #15
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " a"
# Position: #16
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " routine"
# Position: #17
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> routine</span><span title='Token: " check"
# Position: #18
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> check</span><span title='Token: "-"
# Position: #19
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "up"
# Position: #20
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>up</span><span title='Token: " with"
# Position: #21
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " occasional"
# Position: #22
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> occasional</span><span title='Token: " headaches"
# Position: #23
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> headaches</span><span title='Token: " and"
# Position: #24
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> and</span><span title='Token: " fatigue"
# Position: #25
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> fatigue</span><span title='Token: " persist"
# Position: #26
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> persist</span><span title='Token: "ing"
# Position: #27
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>ing</span><span title='Token: " for"
# Position: #28
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " three"
# Position: #29
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> three</span><span title='Token: " months"
# Position: #30
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> months</span><span title='Token: "."
# Position: #31
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>.</span><span title='Token: " The"
# Position: #32
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> The</span><span title='Token: " headaches"
# Position: #33
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> headaches</span><span title='Token: " occur"
# Position: #34
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> occur</span><span title='Token: " "
# Position: #35
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "2"
# Position: #36
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>2</span><span title='Token: "–"
# Position: #37
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>–</span><span title='Token: "3"
# Position: #38
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>3</span><span title='Token: " times"
# Position: #39
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> times</span><span title='Token: " per"
# Position: #40
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> per</span><span title='Token: " week"
# Position: #41
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> week</span><span title='Token: ","
# Position: #42
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " are"
# Position: #43
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> are</span><span title='Token: " mild"
# Position: #44
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> mild</span><span title='Token: " to"
# Position: #45
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> to</span><span title='Token: " moderate"
# Position: #46
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> moderate</span><span title='Token: " with"
# Position: #47
# Activation: 0.0000' style='background-color:
# --- Visualizing Unrelated Text ---
# Loaded probe from probes/elevated_LDL_cholesterol/probe.joblib
# <h2>Activation visualization for concept: 'elevated LDL cholesterol'</h2><div style='line-height: 2.5; font-family: monospace; font-size: 14px;'><span title='Token: "&lt;bos&gt;"
# Position: #0
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&lt;bos&gt;</span><span title='Token: "Michael"
# Position: #1
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>Michael</span><span title='Token: " Chen"
# Position: #2
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> Chen</span><span title='Token: ","
# Position: #3
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " a"
# Position: #4
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " "
# Position: #5
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "3"
# Position: #6
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>3</span><span title='Token: "2"
# Position: #7
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>2</span><span title='Token: "-"
# Position: #8
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "year"
# Position: #9
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>year</span><span title='Token: "-"
# Position: #10
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "old"
# Position: #11
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>old</span><span title='Token: " software"
# Position: #12
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> software</span><span title='Token: " developer"
# Position: #13
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> developer</span><span title='Token: ","
# Position: #14
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " schedules"
# Position: #15
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> schedules</span><span title='Token: " a"
# Position: #16
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " meeting"
# Position: #17
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> meeting</span><span title='Token: " with"
# Position: #18
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " his"
# Position: #19
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> his</span><span title='Token: " team"
# Position: #20
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> team</span><span title='Token: " lead"
# Position: #21
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> lead</span><span title='Token: " to"
# Position: #22
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> to</span><span title='Token: " discuss"
# Position: #23
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> discuss</span><span title='Token: " ongoing"
# Position: #24
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> ongoing</span><span title='Token: " challenges"
# Position: #25
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> challenges</span><span title='Token: " with"
# Position: #26
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " the"
# Position: #27
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> the</span><span title='Token: " company"
# Position: #28
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> company</span><span title='Token: "&#x27;"
# Position: #29
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&#x27;</span><span title='Token: "s"
# Position: #30
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>s</span><span title='Token: " flagship"
# Position: #31
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> flagship</span><span title='Token: " application"
# Position: #32
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> application</span><span title='Token: "."
# Position: #33
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>.</span><span title='Token: " He"
# Position: #34
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> He</span><span title='Token: "&#x27;"
# Position: #35
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&#x27;</span><span title='Token: "s"
# Position: #36
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>s</span><span title='Token: " been"
# Position: #37
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> been</span><span title='Token: " experiencing"
# Position: #38
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> experiencing</span><span title='Token: " intermittent"
# Position: #39
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> intermittent</span><span title='Token: " system"
# Position: #40
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> system</span><span title='Token: " crashes"
# Position: #41
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> crashes</span><span title='Token: " and"
# Position: #42
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> and</span><span title='Token: " performance"
# Position: #43
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> performance</span><span title='Token: " issues"
# Position: #44
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> issues</span><span title='Token: " for"
# Position: #45
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " approximately"
# Position: #46
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; b
# --- Validation Results ---
# Loaded probe from probes/elevated_LDL_cholesterol/probe.joblib
#
# === Activation Validation Results ===
# Concept Key: elevated_LDL_cholesterol
# Concept String: 'elevated LDL cholesterol'
# Example Text Score:   4.2895
# Unrelated Text Score: 0.0259
# Overall Difference:   4.2636
#
# --- Token-Level Contributions (Example Text) ---
# Idx   Token           Group                                    Activation   Similarity   ActVal
# -----------------------------------------------------------------------------------------------------
# 150   ,               His medical history includes hyperten... 1.0000       0.2418       0.2418
# 164   ).              though BP remains mildly elevated (14... 0.9615       0.3267       0.3141
# 252   ).              7 (overweight). Physical exam is unre... 0.0014       0.1992       0.0003
# 361   ,               6% (near prediabetic range). Given hi... 0.9994       0.4665       0.4662
# 371   ,               and high total cholesterol,              0.9514       0.4812       0.4578
# 397   .               in line with Australian guidelines.      1.0000       0.0289       0.0289
# 454   .               should be considered before initiation.  1.0000       -0.0296      0.0296
# 455
#                Answer:
# The LDL-C was 160 which is el... 0.0985       0.6203       0.0611
# 457
#                Answer:
# The LDL-C was 160 which is el... 1.0000       0.6203       0.6203
# 459   :               Answer:
# The LDL-C was 160 which is el... 1.0000       0.6203       0.6203
# 460
#                Answer:
# The LDL-C was 160 which is el... 1.0000       0.6203       0.6203
# 509    has            This patient has dyslipidaemia.          1.0000       0.3116       0.3116
# 514   .               This patient has dyslipidaemia.          0.9989       0.3116       0.3113
# 538    has            The patient has never been on a stati... 0.9997       0.2060       0.2060
#
# --- Token-Level Contributions (Unrelated Text) ---
# Idx   Token           Group                                    Activation   Similarity   ActVal
# -----------------------------------------------------------------------------------------------------
# 462   .               Recommendation:
# The response time of ... 1.0000       -0.0259      0.0259
# 497   .               6GB daily is nearly at capacity.         0.0023       0.0115       0.0000
#
# ============================================
# Concept: low_HDL_cholesterol
#
# --- Visualizing Example Text ---
# Loaded probe from probes/low_HDL_cholesterol/probe.joblib
# <h2>Activation visualization for concept: 'low HDL cholesterol'</h2><div style='line-height: 2.5; font-family: monospace; font-size: 14px;'><span title='Token: "&lt;bos&gt;"
# Position: #0
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&lt;bos&gt;</span><span title='Token: "John"
# Position: #1
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>John</span><span title='Token: " Doe"
# Position: #2
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> Doe</span><span title='Token: ","
# Position: #3
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " a"
# Position: #4
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " "
# Position: #5
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "5"
# Position: #6
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>5</span><span title='Token: "4"
# Position: #7
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>4</span><span title='Token: "-"
# Position: #8
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "year"
# Position: #9
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>year</span><span title='Token: "-"
# Position: #10
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "old"
# Position: #11
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>old</span><span title='Token: " male"
# Position: #12
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> male</span><span title='Token: ","
# Position: #13
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " presents"
# Position: #14
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> presents</span><span title='Token: " for"
# Position: #15
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " a"
# Position: #16
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " routine"
# Position: #17
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> routine</span><span title='Token: " check"
# Position: #18
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> check</span><span title='Token: "-"
# Position: #19
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "up"
# Position: #20
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>up</span><span title='Token: " with"
# Position: #21
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " occasional"
# Position: #22
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> occasional</span><span title='Token: " headaches"
# Position: #23
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> headaches</span><span title='Token: " and"
# Position: #24
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> and</span><span title='Token: " fatigue"
# Position: #25
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> fatigue</span><span title='Token: " persist"
# Position: #26
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> persist</span><span title='Token: "ing"
# Position: #27
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>ing</span><span title='Token: " for"
# Position: #28
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " three"
# Position: #29
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> three</span><span title='Token: " months"
# Position: #30
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> months</span><span title='Token: "."
# Position: #31
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>.</span><span title='Token: " The"
# Position: #32
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> The</span><span title='Token: " headaches"
# Position: #33
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> headaches</span><span title='Token: " occur"
# Position: #34
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> occur</span><span title='Token: " "
# Position: #35
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "2"
# Position: #36
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>2</span><span title='Token: "–"
# Position: #37
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>–</span><span title='Token: "3"
# Position: #38
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>3</span><span title='Token: " times"
# Position: #39
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> times</span><span title='Token: " per"
# Position: #40
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> per</span><span title='Token: " week"
# Position: #41
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> week</span><span title='Token: ","
# Position: #42
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " are"
# Position: #43
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> are</span><span title='Token: " mild"
# Position: #44
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> mild</span><span title='Token: " to"
# Position: #45
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> to</span><span title='Token: " moderate"
# Position: #46
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> moderate</span><span title='Token: " with"
# Position: #47
# Activation: 0.0000' style='background-color: rgb(
# --- Visualizing Unrelated Text ---
# Loaded probe from probes/low_HDL_cholesterol/probe.joblib
# <h2>Activation visualization for concept: 'low HDL cholesterol'</h2><div style='line-height: 2.5; font-family: monospace; font-size: 14px;'><span title='Token: "&lt;bos&gt;"
# Position: #0
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&lt;bos&gt;</span><span title='Token: "Michael"
# Position: #1
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>Michael</span><span title='Token: " Chen"
# Position: #2
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> Chen</span><span title='Token: ","
# Position: #3
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " a"
# Position: #4
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " "
# Position: #5
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "3"
# Position: #6
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>3</span><span title='Token: "2"
# Position: #7
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>2</span><span title='Token: "-"
# Position: #8
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "year"
# Position: #9
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>year</span><span title='Token: "-"
# Position: #10
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "old"
# Position: #11
# ...
# Position: #10
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "old"
# Position: #11
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>old</span><span title='Token: " male"
# Position: #12
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> male</span><span title='Token: ","
# Position: #13
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " presents"
# Position: #14
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> presents</span><span title='Token: " for"
# Position: #15
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " a"
# Position: #16
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " routine"
# Position: #17
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> routine</span><span title='Token: " check"
# Position: #18
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> check</span><span title='Token: "-"
# Position: #19
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "up"
# Position: #20
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>up</span><span title='Token: " with"
# Position: #21
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " occasional"
# Position: #22
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> occasional</span><span title='Token: " headaches"
# Position: #23
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> headaches</span><span title='Token: " and"
# Position: #24
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> and</span><span title='Token: " fatigue"
# Position: #25
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> fatigue</span><span title='Token: " persist"
# Position: #26
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> persist</span><span title='Token: "ing"
# Position: #27
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>ing</span><span title='Token: " for"
# Position: #28
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " three"
# Position: #29
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> three</span><span title='Token: " months"
# Position: #30
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> months</span><span title='Token: "."
# Position: #31
# Activation: 0.0000' style='background-color: rgb(254, 255, 254); padding: 3px; border-radius: 3px; margin: 1px;'>.</span><span title='Token: " The"
# Position: #32
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> The</span><span title='Token: " headaches"
# Position: #33
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> headaches</span><span title='Token: " occur"
# Position: #34
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> occur</span><span title='Token: " "
# Position: #35
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "2"
# Position: #36
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>2</span><span title='Token: "–"
# Position: #37
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>–</span><span title='Token: "3"
# Position: #38
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>3</span><span title='Token: " times"
# Position: #39
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> times</span><span title='Token: " per"
# Position: #40
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> per</span><span title='Token: " week"
# Position: #41
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> week</span><span title='Token: ","
# Position: #42
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " are"
# Position: #43
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> are</span><span title='Token: " mild"
# Position: #44
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> mild</span><span title='Token: " to"
# Position: #45
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> to</span><span title='Token: " moderate"
# Position: #46
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> moderate</span><span title='Token: " with"
# Position: #47
# Activation: 0.0000' style='background-color: rgb(255,
# --- Visualizing Unrelated Text ---
# Loaded probe from probes/hypothyroidism/probe.joblib
# <h2>Activation visualization for concept: 'hypothyroidism'</h2><div style='line-height: 2.5; font-family: monospace; font-size: 14px;'><span title='Token: "&lt;bos&gt;"
# Position: #0
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&lt;bos&gt;</span><span title='Token: "Michael"
# Position: #1
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>Michael</span><span title='Token: " Chen"
# Position: #2
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> Chen</span><span title='Token: ","
# Position: #3
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " a"
# Position: #4
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " "
# Position: #5
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> </span><span title='Token: "3"
# Position: #6
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>3</span><span title='Token: "2"
# Position: #7
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>2</span><span title='Token: "-"
# Position: #8
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "year"
# Position: #9
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>year</span><span title='Token: "-"
# Position: #10
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>-</span><span title='Token: "old"
# Position: #11
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>old</span><span title='Token: " software"
# Position: #12
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> software</span><span title='Token: " developer"
# Position: #13
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> developer</span><span title='Token: ","
# Position: #14
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>,</span><span title='Token: " schedules"
# Position: #15
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> schedules</span><span title='Token: " a"
# Position: #16
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> a</span><span title='Token: " meeting"
# Position: #17
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> meeting</span><span title='Token: " with"
# Position: #18
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " his"
# Position: #19
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> his</span><span title='Token: " team"
# Position: #20
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> team</span><span title='Token: " lead"
# Position: #21
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> lead</span><span title='Token: " to"
# Position: #22
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> to</span><span title='Token: " discuss"
# Position: #23
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> discuss</span><span title='Token: " ongoing"
# Position: #24
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> ongoing</span><span title='Token: " challenges"
# Position: #25
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> challenges</span><span title='Token: " with"
# Position: #26
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> with</span><span title='Token: " the"
# Position: #27
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> the</span><span title='Token: " company"
# Position: #28
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> company</span><span title='Token: "&#x27;"
# Position: #29
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&#x27;</span><span title='Token: "s"
# Position: #30
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>s</span><span title='Token: " flagship"
# Position: #31
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> flagship</span><span title='Token: " application"
# Position: #32
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> application</span><span title='Token: "."
# Position: #33
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>.</span><span title='Token: " He"
# Position: #34
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> He</span><span title='Token: "&#x27;"
# Position: #35
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>&#x27;</span><span title='Token: "s"
# Position: #36
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'>s</span><span title='Token: " been"
# Position: #37
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> been</span><span title='Token: " experiencing"
# Position: #38
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> experiencing</span><span title='Token: " intermittent"
# Position: #39
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> intermittent</span><span title='Token: " system"
# Position: #40
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> system</span><span title='Token: " crashes"
# Position: #41
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> crashes</span><span title='Token: " and"
# Position: #42
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> and</span><span title='Token: " performance"
# Position: #43
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> performance</span><span title='Token: " issues"
# Position: #44
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> issues</span><span title='Token: " for"
# Position: #45
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radius: 3px; margin: 1px;'> for</span><span title='Token: " approximately"
# Position: #46
# Activation: 0.0000' style='background-color: rgb(255, 255, 255); padding: 3px; border-radi
# --- Validation Results ---
# Loaded probe from probes/hypothyroidism/probe.joblib
#
# === Activation Validation Results ===
# Concept Key: hypothyroidism
# Concept String: 'hypothyroidism'
# Example Text Score:   0.9122
# Unrelated Text Score: 0.0000
# Overall Difference:   0.9122
#
# --- Token-Level Contributions (Example Text) ---
# Idx   Token           Group                                    Activation   Similarity   ActVal
# -----------------------------------------------------------------------------------------------------
# 164   ).              though BP remains mildly elevated (14... 1.0000       0.2085       0.2085
# 252   ).              7 (overweight). Physical exam is unre... 0.2201       0.1634       0.0360
# 271    reveal         Laboratory investigations reveal dysl... 0.0261       0.1443       0.0038
# 275   :               Laboratory investigations reveal dysl... 0.0011       0.1443       0.0002
# 329   ).              Laboratory investigations reveal dysl... 0.8072       0.1443       0.1165
# 454   .               should be considered before initiation.  1.0000       -0.0036      0.0036
# 473   .               Answer:
# The LDL-C was 160 which is el... 0.9992       0.0998       0.0997
# 494   .               The HDL-C was 42 which is borderline ... 0.9994       0.1323       0.1322
# 506   .               The total cholesterol was 230 which i... 1.0000       0.0678       0.0678
# 514   .               This patient has dyslipidaemia.          0.8516       0.2863       0.2438
#
# No non-zero activations found for Unrelated Text.
